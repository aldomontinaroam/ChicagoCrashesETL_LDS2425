# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# utility functions
def load_data(path):
    data = pd.read_csv(path)
    return data

# %%
data = load_data('Crashes.csv')

# %% [markdown]
# # Info, missing, duplicates

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257925 entries, 0 to 257924
# Data columns (total 36 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   RD_NO                          257925 non-null  object
#  1   CRASH_DATE                     257925 non-null  object
#  2   POSTED_SPEED_LIMIT             257925 non-null  int64
#  3   TRAFFIC_CONTROL_DEVICE         257925 non-null  object
#  4   DEVICE_CONDITION               257925 non-null  object
#  5   WEATHER_CONDITION              257925 non-null  object
#  6   LIGHTING_CONDITION             257925 non-null  object
#  7   FIRST_CRASH_TYPE               257925 non-null  object
#  8   TRAFFICWAY_TYPE                257925 non-null  object
#  9   ALIGNMENT                      257925 non-null  object
#  10  ROADWAY_SURFACE_COND           257925 non-null  object
#  11  ROAD_DEFECT                    257925 non-null  object
#  12  REPORT_TYPE                    252929 non-null  object
#  13  CRASH_TYPE                     257925 non-null  object
#  14  DATE_POLICE_NOTIFIED           257925 non-null  object
#  15  PRIM_CONTRIBUTORY_CAUSE        257925 non-null  object
#  16  SEC_CONTRIBUTORY_CAUSE         257925 non-null  object
#  17  STREET_NO                      257925 non-null  int64
#  18  STREET_DIRECTION               257923 non-null  object
#  19  STREET_NAME                    257924 non-null  object
#  20  BEAT_OF_OCCURRENCE             257921 non-null  float64
#  21  NUM_UNITS                      257925 non-null  float64
#  22  MOST_SEVERE_INJURY             257918 non-null  object
#  23  INJURIES_TOTAL                 257925 non-null  float64
#  24  INJURIES_FATAL                 257925 non-null  float64
#  25  INJURIES_INCAPACITATING        257925 non-null  float64
#  26  INJURIES_NON_INCAPACITATING    257925 non-null  float64
#  27  INJURIES_REPORTED_NOT_EVIDENT  257925 non-null  float64
#  28  INJURIES_NO_INDICATION         257925 non-null  float64
#  29  INJURIES_UNKNOWN               257925 non-null  float64
#  30  CRASH_HOUR                     257925 non-null  int64
#  31  CRASH_DAY_OF_WEEK              257925 non-null  int64
#  32  CRASH_MONTH                    257925 non-null  int64
#  33  LATITUDE                       256903 non-null  float64
#  34  LONGITUDE                      256903 non-null  float64
#  35  LOCATION                       256903 non-null  object
# dtypes: float64(11), int64(5), object(20)
# memory usage: 70.8+ MB

# %%
data.head()
# Out:
#       RD_NO              CRASH_DATE  POSTED_SPEED_LIMIT  \
# 0  JC113649  01/12/2019 12:01:00 AM                  30
# 1  JC113627  01/11/2019 11:36:00 PM                  30
# 2  JC113637  01/11/2019 11:31:00 PM                  15
# 3  JC113630  01/11/2019 11:22:00 PM                  35
# 4  JC113604  01/11/2019 11:08:00 PM                  30
#
#   TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION WEATHER_CONDITION  \
# 0            NO CONTROLS           NO CONTROLS             CLEAR
# 1      STOP SIGN/FLASHER  FUNCTIONING PROPERLY             CLEAR
# 2      STOP SIGN/FLASHER  FUNCTIONING PROPERLY             CLEAR
# 3            NO CONTROLS           NO CONTROLS             CLEAR
# 4         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
#
#        LIGHTING_CONDITION              FIRST_CRASH_TYPE TRAFFICWAY_TYPE  \
# 0  DARKNESS, LIGHTED ROAD          PARKED MOTOR VEHICLE     NOT DIVIDED
# 1  DARKNESS, LIGHTED ROAD                         ANGLE     NOT DIVIDED
# 2                DARKNESS  SIDESWIPE OPPOSITE DIRECTION     NOT DIVIDED
# 3                DARKNESS          PARKED MOTOR VEHICLE     NOT DIVIDED
# 4  DARKNESS, LIGHTED ROAD                      REAR END     NOT DIVIDED
#
#             ALIGNMENT  ... INJURIES_NON_INCAPACITATING  \
# 0  STRAIGHT AND LEVEL  ...                         0.0
# 1  STRAIGHT AND LEVEL  ...                         0.0
# 2  STRAIGHT AND LEVEL  ...                         0.0
# 3  STRAIGHT AND LEVEL  ...                         0.0
# 4  STRAIGHT AND LEVEL  ...                         0.0
#
#   INJURIES_REPORTED_NOT_EVIDENT INJURIES_NO_INDICATION INJURIES_UNKNOWN  \
# 0                           0.0                    1.0              0.0
# 1                           0.0                    2.0              0.0
# 2                           0.0                    2.0              0.0
# 3                           0.0                    1.0              0.0
# 4                           0.0                    3.0              0.0
#
#   CRASH_HOUR CRASH_DAY_OF_WEEK CRASH_MONTH   LATITUDE  LONGITUDE  \
# 0          0                 7           1  41.894718 -87.716439
# 1         23                 6           1  41.961558 -87.757564
# 2         23                 6           1  41.791460 -87.715908
# 3         23                 6           1  41.876779 -87.741695
# 4         23                 6           1  41.960921 -87.739893
#
#                                    LOCATION
# 0  POINT (-87.716439109795 41.894718028422)
# 1  POINT (-87.757564024038 41.961557797444)
# 2  POINT (-87.715907858157 41.791459913725)
# 3  POINT (-87.741694507685 41.876778736117)
# 4  POINT (-87.739893056441 41.960920858153)
#
# [5 rows x 36 columns]

# %%
min_date = pd.to_datetime(data['CRASH_DATE']).min()
max_date = pd.to_datetime(data['CRASH_DATE']).max()

print(f"The range of dates is from {min_date} to {max_date}.")
# Out:
# The range of dates is from 2014-01-18 18:14:00 to 2019-01-12 00:01:00.

# %%
data.duplicated().sum()
# Out:
# 0

# %%
null_columns = data.columns[data.isnull().any()]
null_rows = data.isnull().any(axis=1).sum()

print(f"Number of rows with nulls: {null_rows}\n")

# List to store the results
nulls_info_list = []

# Populate the list with the information
for col in null_columns:
    num_nulls = data[col].isnull().sum()
    pct_nulls = num_nulls / len(data[col]) * 100
    dtype = data[col].dtype
    if dtype == 'object':
        num_unique = data[col].nunique()
        random_value = data[col].dropna().sample(1).values[0]
    else:
        num_unique = '-'
        random_value = '-'
    nulls_info_list.append({
        'Column': col,
        'Num_Nulls': num_nulls,
        'Pct_Nulls': pct_nulls,
        'Type': dtype,
        'Num_Unique': num_unique,
        'Random_Value': random_value
    })

pd.DataFrame(nulls_info_list).sort_values(by='Num_Nulls', ascending=False)
# Out:
# Number of rows with nulls: 6016
#                Column  Num_Nulls  Pct_Nulls     Type Num_Unique  \
# 0         REPORT_TYPE       4996   1.936997   object          2
# 5            LATITUDE       1022   0.396239  float64          -
# 6           LONGITUDE       1022   0.396239  float64          -
# 7            LOCATION       1022   0.396239   object     132461
# 4  MOST_SEVERE_INJURY          7   0.002714   object          5
# 3  BEAT_OF_OCCURRENCE          4   0.001551  float64          -
# 1    STREET_DIRECTION          2   0.000775   object          4
# 2         STREET_NAME          1   0.000388   object       1479
#
#                                Random_Value
# 0                NOT ON SCENE (DESK REPORT)
# 5                                         -
# 6                                         -
# 7  POINT (-87.639758684881 41.881994338205)
# 4                   NO INDICATION OF INJURY
# 3                                         -
# 1                                         S
# 2                                CICERO AVE

# %% [markdown]
# 1. **REPORT_TYPE**: This column contains information about the type of report (e.g., 'ON SCENE', 'NOT ON SCENE (DESK REPORT)'). This type of data is usually specific to the dataset and may not be available online.
# 2. **STREET_DIRECTION**: This column contains street directions (e.g., 'S' for South). Street directions are generally standardized and can be found online, but the specific context (e.g., related to a particular dataset) may not be available.
# 3. **STREET_NAME**: This column contains street names (e.g., 'DIVERSEY AVE'). Street names are publicly available and can be retrieved online from various sources like maps or city databases.
# 4. **BEAT_OF_OCCURRENCE**: This column contains information about the beat of occurrence, which is likely specific to a particular dataset or organization (e.g., police beats). This data may not be readily available online.
# 5. **MOST_SEVERE_INJURY**: This column contains information about the severity of injuries (e.g., 'NO INDICATION OF INJURY'). This type of data is usually specific to the dataset and may not be available online.
# 6. **LATITUDE** and **LONGITUDE**: These columns contain geographical coordinates. Latitude and longitude data can be retrieved online from various mapping services.
# 7. **LOCATION**: This column contains location data in the form of geographical coordinates (e.g., 'POINT (-87.712665377938 41.939731753033)'). Location data can be retrieved online from various mapping services.
#
# We will try to retrieve missing data for street direction, street names, lat-lng and location from external accessible sources online.

# %% [markdown]
# # Insights

# %%
data.describe().T
# Out:
#                                   count         mean          std         min  \
# POSTED_SPEED_LIMIT             257925.0    28.163877     6.916950    0.000000
# STREET_NO                      257925.0  3573.144879  2948.210235    0.000000
# BEAT_OF_OCCURRENCE             257921.0  1242.046662   713.282194  111.000000
# NUM_UNITS                      257925.0     2.022797     0.400398    1.000000
# INJURIES_TOTAL                 257925.0     0.153463     0.505677    0.000000
# INJURIES_FATAL                 257925.0     0.000888     0.032641    0.000000
# INJURIES_INCAPACITATING        257925.0     0.016861     0.151624    0.000000
# INJURIES_NON_INCAPACITATING    257925.0     0.082249     0.365792    0.000000
# INJURIES_REPORTED_NOT_EVIDENT  257925.0     0.053465     0.295557    0.000000
# INJURIES_NO_INDICATION         257925.0     2.033083     1.160398    0.000000
# INJURIES_UNKNOWN               257925.0     0.000000     0.000000    0.000000
# CRASH_HOUR                     257925.0    13.205533     5.417016    0.000000
# CRASH_DAY_OF_WEEK              257925.0     4.123672     1.962760    1.000000
# CRASH_MONTH                    257925.0     7.100300     3.455800    1.000000
# LATITUDE                       256903.0    41.860618     0.084708   41.644670
# LONGITUDE                      256903.0   -87.677238     0.057564  -87.925036
#
#                                        25%          50%          75%  \
# POSTED_SPEED_LIMIT               30.000000    30.000000    30.000000
# STREET_NO                      1158.000000  3100.000000  5501.000000
# BEAT_OF_OCCURRENCE              712.000000  1214.000000  1824.000000
# NUM_UNITS                         2.000000     2.000000     2.000000
# INJURIES_TOTAL                    0.000000     0.000000     0.000000
# INJURIES_FATAL                    0.000000     0.000000     0.000000
# INJURIES_INCAPACITATING           0.000000     0.000000     0.000000
# INJURIES_NON_INCAPACITATING       0.000000     0.000000     0.000000
# INJURIES_REPORTED_NOT_EVIDENT     0.000000     0.000000     0.000000
# INJURIES_NO_INDICATION            1.000000     2.000000     2.000000
# INJURIES_UNKNOWN                  0.000000     0.000000     0.000000
# CRASH_HOUR                        9.000000    14.000000    17.000000
# CRASH_DAY_OF_WEEK                 2.000000     4.000000     6.000000
# CRASH_MONTH                       4.000000     8.000000    10.000000
# LATITUDE                         41.786976    41.878039    41.924490
# LONGITUDE                       -87.719488   -87.671287   -87.632427
#
#                                          max
# POSTED_SPEED_LIMIT                 99.000000
# STREET_NO                      451100.000000
# BEAT_OF_OCCURRENCE               2535.000000
# NUM_UNITS                          18.000000
# INJURIES_TOTAL                     21.000000
# INJURIES_FATAL                      3.000000
# INJURIES_INCAPACITATING             7.000000
# INJURIES_NON_INCAPACITATING        21.000000
# INJURIES_REPORTED_NOT_EVIDENT      10.000000
# INJURIES_NO_INDICATION             61.000000
# INJURIES_UNKNOWN                    0.000000
# CRASH_HOUR                         23.000000
# CRASH_DAY_OF_WEEK                   7.000000
# CRASH_MONTH                        12.000000
# LATITUDE                           42.022780
# LONGITUDE                         -87.524589

# %%
# Convert the CRASH_DATE column to datetime format
data['CRASH_DATE'] = pd.to_datetime(data['CRASH_DATE'])

# Extract day of the week, month, and hour from the CRASH_DATE
data['CRASH_DAY_OF_WEEK'] = data['CRASH_DATE'].dt.day_name()
data['CRASH_MONTH'] = data['CRASH_DATE'].dt.month_name()
data['CRASH_HOUR'] = data['CRASH_DATE'].dt.hour

# Create a figure with three subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot the countplot for CRASH_DAY_OF_WEEK
sns.countplot(ax=axes[0], x='CRASH_DAY_OF_WEEK', data=data, order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
axes[0].set_title('Distribution of Crashes by Day of the Week')
axes[0].set_xlabel('Day of the Week')
axes[0].set_ylabel('Count')

# Plot the countplot for CRASH_MONTH
sns.countplot(ax=axes[1], x='CRASH_MONTH', data=data, order=['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
axes[1].set_title('Distribution of Crashes by Month')
axes[1].set_xlabel('Month')
axes[1].set_ylabel('Count')

# Plot the countplot for CRASH_HOUR
sns.countplot(ax=axes[2], x='CRASH_HOUR', data=data)
axes[2].set_title('Distribution of Crashes by Hour')
axes[2].set_xlabel('Hour of the Day')
axes[2].set_ylabel('Count')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
data.describe(include=['object']).T
# Out:
#                           count  unique  \
# RD_NO                    257925  257925
# CRASH_DATE               257925  166465
# TRAFFIC_CONTROL_DEVICE   257925      15
# DEVICE_CONDITION         257925       8
# WEATHER_CONDITION        257925       9
# LIGHTING_CONDITION       257925       6
# FIRST_CRASH_TYPE         257925      15
# TRAFFICWAY_TYPE          257925      11
# ALIGNMENT                257925       6
# ROADWAY_SURFACE_COND     257925       7
# ROAD_DEFECT              257925       7
# REPORT_TYPE              252929       2
# CRASH_TYPE               257925       2
# DATE_POLICE_NOTIFIED     257925  198405
# PRIM_CONTRIBUTORY_CAUSE  257925      38
# SEC_CONTRIBUTORY_CAUSE   257925      38
# STREET_DIRECTION         257923       4
# STREET_NAME              257924    1479
# MOST_SEVERE_INJURY       257918       5
# LOCATION                 256903  132461
#
#                                                               top    freq
# RD_NO                                                    JC113649       1
# CRASH_DATE                                 11/10/2017 10:30:00 AM      27
# TRAFFIC_CONTROL_DEVICE                                NO CONTROLS  148894
# DEVICE_CONDITION                                      NO CONTROLS  150267
# WEATHER_CONDITION                                           CLEAR  205435
# LIGHTING_CONDITION                                       DAYLIGHT  169330
# FIRST_CRASH_TYPE                                         REAR END   65883
# TRAFFICWAY_TYPE                                       NOT DIVIDED  118692
# ALIGNMENT                                      STRAIGHT AND LEVEL  251633
# ROADWAY_SURFACE_COND                                          DRY  195116
# ROAD_DEFECT                                            NO DEFECTS  215423
# REPORT_TYPE                            NOT ON SCENE (DESK REPORT)  167961
# CRASH_TYPE                                 NO INJURY / DRIVE AWAY  203310
# DATE_POLICE_NOTIFIED                       06/30/2018 09:30:00 PM      11
# PRIM_CONTRIBUTORY_CAUSE                       UNABLE TO DETERMINE   92595
# SEC_CONTRIBUTORY_CAUSE                             NOT APPLICABLE   98850
# STREET_DIRECTION                                                W   91031
# STREET_NAME                                           WESTERN AVE    7041
# MOST_SEVERE_INJURY                        NO INDICATION OF INJURY  228475
# LOCATION                 POINT (-87.905309125103 41.976201139024)     214

# %%
'''import re

# Function to identify and convert probable date columns
def identify_and_convert_dates(df):
    date_pattern = re.compile(r'\d{2}/\d{2}/\d{4} \d{2}:\d{2}:\d{2} (AM|PM)')
    probable_date_columns = []

    for col in df.select_dtypes(include=['object']).columns:
        if df[col].apply(lambda x: bool(date_pattern.match(str(x)))).any():
            probable_date_columns.append(col)
            df[col] = pd.to_datetime(df[col], format='%m/%d/%Y %I:%M:%S %p')

    return probable_date_columns

# Example usage
identify_and_convert_dates(data)'''
# Out:
# "import re\n\n# Function to identify and convert probable date columns\ndef identify_and_convert_dates(df):\n    date_pattern = re.compile(r'\\d{2}/\\d{2}/\\d{4} \\d{2}:\\d{2}:\\d{2} (AM|PM)')\n    probable_date_columns = []\n\n    for col in df.select_dtypes(include=['object']).columns:\n        if df[col].apply(lambda x: bool(date_pattern.match(str(x)))).any():\n            probable_date_columns.append(col)\n            df[col] = pd.to_datetime(df[col], format='%m/%d/%Y %I:%M:%S %p')\n\n    return probable_date_columns\n\n# Example usage\nidentify_and_convert_dates(data)"

# %%
from dataprep.eda import plot, plot_correlation, create_report, plot_missing
create_report(data)

# %%
data.columns
# Out:
# Index(['RD_NO', 'CRASH_DATE', 'POSTED_SPEED_LIMIT', 'TRAFFIC_CONTROL_DEVICE',
#        'DEVICE_CONDITION', 'WEATHER_CONDITION', 'LIGHTING_CONDITION',
#        'FIRST_CRASH_TYPE', 'TRAFFICWAY_TYPE', 'ALIGNMENT',
#        'ROADWAY_SURFACE_COND', 'ROAD_DEFECT', 'REPORT_TYPE', 'CRASH_TYPE',
#        'DATE_POLICE_NOTIFIED', 'PRIM_CONTRIBUTORY_CAUSE',
#        'SEC_CONTRIBUTORY_CAUSE', 'STREET_NO', 'STREET_DIRECTION',
#        'STREET_NAME', 'BEAT_OF_OCCURRENCE', 'NUM_UNITS', 'MOST_SEVERE_INJURY',
#        'INJURIES_TOTAL', 'INJURIES_FATAL', 'INJURIES_INCAPACITATING',
#        'INJURIES_NON_INCAPACITATING', 'INJURIES_REPORTED_NOT_EVIDENT',
#        'INJURIES_NO_INDICATION', 'INJURIES_UNKNOWN', 'CRASH_HOUR',
#        'CRASH_DAY_OF_WEEK', 'CRASH_MONTH', 'LATITUDE', 'LONGITUDE',
#        'LOCATION'],
#       dtype='object')

# %%
data.set_index('CRASH_DATE')['INJURIES_TOTAL'].plot(figsize=(12,6))
# Out:
# <Axes: xlabel='CRASH_DATE'>

# %%
# Get the location with the highest count
most_common_location = data['LOCATION'].value_counts().idxmax()
count = data['LOCATION'].value_counts().max()

most_common_location
# Out:
# 'POINT (-87.905309125103 41.976201139024)'

# %% [markdown]
# # Data Cleaning
# Missing values

# %% [markdown]
# # Data Integration

# %% [markdown]
# # Data prep (I)
# - Datetime conversion
# - String format
# - Handle geo data (?)
